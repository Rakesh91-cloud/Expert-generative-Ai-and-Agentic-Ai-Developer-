# %% [markdown]
# # 3rd --python datastructure

# %% [markdown]
# 1.list
# 2.tuple
# 3.set
# 4.dict

# %%
l=[]

# %%
[]
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l
# Out:
# [10, 20, 30, 40]

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l1.append('hi',1+2j,2.3,True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l1.append('hi',1+2j,2.3,True)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
l1.append('hi')

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi']

# %%
l1.append(2.4)
l1.append(2+3j)
l1.append('True')

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', 2.4, (2+3j), 'True']

# %%
print(l)
# Out:
# [10, 20, 30, 40]

# %%
print(l1)
# Out:
# [10, 20, 30, 40, 'hi', 2.4, (2+3j), 'True']

# %%
print(len(l))
print(len(l1))
# Out:
# 4
# 8

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l3=[1,3,4,5,6,7,8,'praksh','senapati',1+2j,True]

# %%
l3.clear
# Out:
# <function list.clear()>

# %%
l3.clear()

# %%
l3
# Out:
# []

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l.count(20)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l[:]
# Out:
# [10, 20, 30, 40, 10]

# %%
l[2:]
# Out:
# [30, 40, 10]

# %%
l[3:]
# Out:
# [40, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[:2]
# Out:
# [10, 20]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[:1]
# Out:
# [10]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[::-1]
# Out:
# [10, 40, 30, 20, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[:::-1] #ony two slice
# Out:
#   Cell In[40], line 1
#     l[:::-1]
#         ^
# SyntaxError: invalid syntax

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', 2.4, (2+3j), 'True']

# %%
l1.index('prakash')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 l1.index('prakash')
#
# ValueError: list.index(x): x not in list

# %%
l1.index('prakash')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 l1.index('prakash')
#
# ValueError: list.index(x): x not in list

# %%
l[::1]
# Out:
# [10, 20, 30, 40, 10]

# %%
l[::2]
# Out:
# [10, 30, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', 2.4, (2+3j), 'True']

# %%
l1.append('prakash')

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', 2.4, (2+3j), 'True', 'prakash']

# %%
l1.del('praksh')
# Out:
#   Cell In[50], line 1
#     l1.del('praksh')
#        ^
# SyntaxError: invalid syntax

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', 2.4, (2+3j), 'True', 'prakash']

# %%
l1[::2]
# Out:
# [10, 30, 'hi', (2+3j), 'prakash']

# %%
l1[3:5:6]
# Out:
# [40]

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', 2.4, (2+3j), 'True', 'prakash']

# %%
l
# Out:
# [10, 20, 30, 40, 10]
