# %% [markdown]
# # we work with python and number

# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
-5
# Out:
# -5

# %%
5+6
# Out:
# 11

# %%
5+6-7*3-7
# Out:
# -17

# %%
5+6-7*(3-7)
# Out:
# 39

# %% [markdown]
# # store previous output

# %%
_+3
# Out:
# 42

# %%
_=4

# %%
_-4
# Out:
# 0

# %%
3+4-2
# Out:
# 5

# %%
3+(4-2)
# Out:
# 5

# %% [markdown]
# # work with text(string)

# %%
'nareshit'
# Out:
# 'nareshit'

# %%
"nareshit"
# Out:
# 'nareshit'

# %%
'''nareshit'''
# Out:
# 'nareshit'

# %%
''' nareshit
         technology'''
# Out:
# ' nareshit\n         technology'

# %% [markdown]
# # basics string completed

# %% [markdown]
# # 28th

# %%
v=5
v
# Out:
# 5

# %%
id(v)
# Out:
# 140708299728120

# %%
nit=8
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 nit=8
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
8=nit
# Out:
#   Cell In[19], line 1
#     8=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
nit8=10
nit8
# Out:
# 10

# %%
nit_=78
nit
# Out:
# 8

# %%
import keyword 
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
3+4
7+7
4-1
# Out:
# 3

# %% [raw]
# print(3+4)
# print(7+7)
# print(4-1)

# %%
print(3+4)
print(7+7)
print(4-1)
# Out:
# 7
# 14
# 3

# %%
nit=10
nit
# Out:
# 10

# %%
a=5
a
print(a)
# Out:
# 5

# %%
i=56
i
print(i)
# Out:
# 56

# %%
f1=1e0
print(f1)
# Out:
# 1.0

# %%
f2=1e1
print(f2)
# Out:
# 10.0

# %%
f3=2.3e3
f3
print(f3)
# Out:
# 2300.0

# %% [markdown]
# # Boollean

# %%
a=True
b=False
c=a+b
d=a-b
e=a*b

print(c)
print(d)
print(a)
print(e)
# Out:
# 1
# 1
# True
# 0

# %% [markdown]
# # Complex

# %%
c=10+20j

# %%
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %% [markdown]
# int = value without  decimal
# float= value with decimal
# bool=True or False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
False+True
# Out:
# 1

# %%
c1=30+4.5j
c1
# Out:
# (30+4.5j)

# %% [markdown]
# ##

# %%
c2=4.4+20j
c2
# Out:
# (4.4+20j)

# %% [markdown]
# # String

# %%
s='prakash'

# %%
s[0]
# Out:
# 'p'

# %%
s[-7]
# Out:
# 'p'

# %%
s[2]
# Out:
# 'a'

# %%
s[3]
# Out:
# 'k'

# %%
s[4]
# Out:
# 'a'

# %%
s[5]
# Out:
# 's'

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 s[7]
#
# IndexError: string index out of range

# %%
s[6]
# Out:
# 'h'

# %%
s{10}
# Out:
#   Cell In[56], line 1
#     s{10}
#      ^
# SyntaxError: invalid syntax

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s[-7]
# Out:
# 'p'

# %%
s[-1]
# Out:
# 'h'

# %%
s= 'Nana+Bau'

# %%
s[0]
# Out:
# 'N'

# %%
s[1]
# Out:
# 'a'

# %%
s[2]
# Out:
# 'n'

# %%
s[3]
# Out:
# 'a'

# %%
s[4]
# Out:
# '+'

# %%
s[5]
# Out:
# 'B'

# %%
s[6]
# Out:
# 'a'

# %%
s[7]
# Out:
# 'u'

# %%
s[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 s[8]
#
# IndexError: string index out of range

# %%
s[-1]
# Out:
# 'u'

# %%
s[-2]
# Out:
# 'a'

# %%
s[-3]
# Out:
# 'B'

# %%
s[-4]
# Out:
# '+'

# %%
s[5]
# Out:
# 'B'

# %%
s[6]
# Out:
# 'a'

# %%
s[7]
# Out:
# 'u'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %% [markdown]
# # Slicing

# %%
s[:]
# Out:
# 'Nana+Bau'

# %%
s[1:]
# Out:
# 'ana+Bau'

# %%
s[2:]
# Out:
# 'na+Bau'

# %%
s[3:]
# Out:
# 'a+Bau'

# %%
s[4:]
# Out:
# '+Bau'

# %%
s[5:]
# Out:
# 'Bau'

# %%
s[6:]
# Out:
# 'au'

# %%
s
# Out:
# 'Nana+Bau'

# %%
'prakash'
# Out:
# 'prakash'

# %%
s
# Out:
# 'Nana+Bau'

# %%
s='prakash'

# %%
s
# Out:
# 'prakash'

# %%
s[1:]
# Out:
# 'rakash'

# %%
s[2:]
# Out:
# 'akash'

# %%
s[3:]
# Out:
# 'kash'

# %%
s[4:]
# Out:
# 'ash'

# %%
s[5:]
# Out:
# 'sh'

# %%
s[:]
# Out:
# 'prakash'

# %%
s[:1]
# Out:
# 'p'

# %%
s[1:]
# Out:
# 'rakash'

# %%
s[2:]
# Out:
# 'akash'

# %%
s[:2]
# Out:
# 'pr'

# %%
s[3:]
# Out:
# 'kash'

# %%
s[:3]
# Out:
# 'pra'

# %%
s[4:]
# Out:
# 'ash'

# %%
s[:4]
# Out:
# 'prak'

# %%
s
# Out:
# 'prakash'

# %%
s[2:]
# Out:
# 'akash'
